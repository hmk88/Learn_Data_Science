# %% [markdown]
# <a href="https://colab.research.google.com/github/hmk88/Learn_Data_Science/blob/master/Time_series_Python_Handbook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import datetime
datetime(year=2019, month=11, day=1)
# Out:
# datetime.datetime(2019, 11, 1, 0, 0)

# %%
from dateutil import parser 
date = parser.parse("1st of November 2019")

# %%
date.strftime('%A')
# Out:
# 'Friday'

# %%
import numpy as np
date = np.array('2019-11-01', dtype=np.datetime64)
date
# Out:
# array('2019-11-01', dtype='datetime64[D]')

# %%
date + np.arange(10)
# Out:
# array(['2019-11-01', '2019-11-02', '2019-11-03', '2019-11-04',
#        '2019-11-05', '2019-11-06', '2019-11-07', '2019-11-08',
#        '2019-11-09', '2019-11-10'], dtype='datetime64[D]')

# %%
#day based datetime
np.datetime64('2019-11-01')
# Out:
# numpy.datetime64('2019-11-01')

# %%
#minute based datetime
np.datetime64('2019-11-01 00:00')
# Out:
# numpy.datetime64('2019-11-01T00:00')

# %%
##Nano second based time initialization 
####Code	Meaning	Time span (relative)	Time span (absolute)
#### Y	  Year	      ± 9.2e18 years	[9.2e18 BC, 9.2e18 AD]
#### M	  Month	      ± 7.6e17 years	[7.6e17 BC, 7.6e17 AD]
#### W	  Week	      ± 1.7e17 years	[1.7e17 BC, 1.7e17 AD]
#### D	  Day	        ± 2.5e16 years	[2.5e16 BC, 2.5e16 AD]
#### h	 Hour	        ± 1.0e15 years	[1.0e15 BC, 1.0e15 AD]
#### m	 Minute	      ± 1.7e13 years	[1.7e13 BC, 1.7e13 AD]
#### s	 Second	      ± 2.9e12 years	[ 2.9e9 BC, 2.9e9 AD]
#### ms	 Millisecond	± 2.9e9 years	[ 2.9e6 BC, 2.9e6 AD]
#### us	 Microsecond	± 2.9e6 years	[290301 BC, 294241 AD]
#### ns	 Nanosecond	  ± 292 years	[ 1678 AD, 2262 AD]
#### ps	 Picosecond	  ±  106 days	[ 1969 AD, 1970 AD]
#### fs	 Femtosecond	± 2.6 hours	[ 1969 AD, 1970 AD]
#### as	 Attosecond	  ± 9.2 seconds	[ 1969 AD, 1970 AD]
np.datetime64('2019-11-01 11:53:55.1', 'ns')
# Out:
# numpy.datetime64('2019-11-01T11:53:55.100000000')

# %%
import pandas as pd 
date = pd.to_datetime('1st of Nov, 2019')
date
# Out:
# Timestamp('2019-11-01 00:00:00')

# %%
date + pd.to_timedelta(np.arange(12), 'D')
# Out:
# DatetimeIndex(['2019-11-01', '2019-11-02', '2019-11-03', '2019-11-04',
#                '2019-11-05', '2019-11-06', '2019-11-07', '2019-11-08',
#                '2019-11-09', '2019-11-10', '2019-11-11', '2019-11-12'],
#               dtype='datetime64[ns]', freq=None)

# %%
index = pd.DatetimeIndex(['2019-11-01', '2019-10-01',
                          '2019-11-02', '2019-10-02'])
data = pd.Series([0, 1, 2, 3], index = index)
data
# Out:
# 2019-11-01    0
# 2019-10-01    1
# 2019-11-02    2
# 2019-10-02    3
# dtype: int64

# %%
data['2019-11-01':'2019-11-02']
# Out:
# 2019-11-01    0
# 2019-11-02    2
# dtype: int64

# %%
data['2019']
# Out:
# 2019-11-01    0
# 2019-10-01    1
# 2019-11-02    2
# 2019-10-02    3
# dtype: int64

# %%
data.to_period('H')
# Out:
# 2019-11-01 00:00    0
# 2019-10-01 00:00    1
# 2019-11-02 00:00    2
# 2019-10-02 00:00    3
# Freq: H, dtype: int64

# %%
#Date range from point one to another 
date= pd.date_range('2018-01-01', '2018-06-30')
date
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06', '2018-01-07', '2018-01-08',
#                '2018-01-09', '2018-01-10',
#                ...
#                '2018-06-21', '2018-06-22', '2018-06-23', '2018-06-24',
#                '2018-06-25', '2018-06-26', '2018-06-27', '2018-06-28',
#                '2018-06-29', '2018-06-30'],
#               dtype='datetime64[ns]', length=181, freq='D')

# %%
#Date range by giving number of period
date=pd.date_range('2018-01-01', periods= 181, freq='H')
date
# Out:
# DatetimeIndex(['2018-01-01 00:00:00', '2018-01-01 01:00:00',
#                '2018-01-01 02:00:00', '2018-01-01 03:00:00',
#                '2018-01-01 04:00:00', '2018-01-01 05:00:00',
#                '2018-01-01 06:00:00', '2018-01-01 07:00:00',
#                '2018-01-01 08:00:00', '2018-01-01 09:00:00',
#                ...
#                '2018-01-08 03:00:00', '2018-01-08 04:00:00',
#                '2018-01-08 05:00:00', '2018-01-08 06:00:00',
#                '2018-01-08 07:00:00', '2018-01-08 08:00:00',
#                '2018-01-08 09:00:00', '2018-01-08 10:00:00',
#                '2018-01-08 11:00:00', '2018-01-08 12:00:00'],
#               dtype='datetime64[ns]', length=181, freq='H')

# %%
#Create regular sequence of period 
pd.period_range('2019-01', periods=10, freq='M')
# Out:
# PeriodIndex(['2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06',
#              '2019-07', '2019-08', '2019-09', '2019-10'],
#             dtype='period[M]', freq='M')

# %%
#Create regular sequence of hourly period
pd.timedelta_range(0, periods=10, freq='H')
# Out:
# TimedeltaIndex(['00:00:00', '01:00:00', '02:00:00', '03:00:00', '04:00:00',
#                 '05:00:00', '06:00:00', '07:00:00', '08:00:00', '09:00:00'],
#                dtype='timedelta64[ns]', freq='H')

# %%
#Code	Description	Code	Description
#D	Calendar day	  B	Business day
#W	Weekly		
#M	Month end	      BM	Business month end
#Q	Quarter end	    BQ	Business quarter end
#A	Year end	      BA	Business year end
#H	Hours	          BH	Business hours
#T	Minutes		
#S	Seconds		
#L	Milliseonds		
#U	Microseconds		
#N	nanoseconds	

#Code	Description		Code	Description
#MS	Month start		  BMS	Business month start
#QS	Quarter start		BQS	Business quarter start
#AS	Year start		  BAS	Business year start	

#Q-JAN, BQ-FEB, QS-MAR, BQS-APR, etc.
#A-JAN, BA-FEB, AS-MAR, BAS-APR, etc.

# %%
#Create time range 
pd.timedelta_range(0, periods=10, freq='2H30T')
# Out:
# TimedeltaIndex(['00:00:00', '02:30:00', '05:00:00', '07:30:00', '10:00:00',
#                 '12:30:00', '15:00:00', '17:30:00', '20:00:00', '22:30:00'],
#                dtype='timedelta64[ns]', freq='150T')

# %%
from pandas.tseries.offsets import BDay
pd.date_range('2019-11-01', periods=10, freq=BDay())
# Out:
# DatetimeIndex(['2019-11-01', '2019-11-04', '2019-11-05', '2019-11-06',
#                '2019-11-07', '2019-11-08', '2019-11-11', '2019-11-12',
#                '2019-11-13', '2019-11-14'],
#               dtype='datetime64[ns]', freq='B')

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/hmk88/Tensorflow_Baiscs/master/Vaasa_weather.csv'
df1 = pd.read_csv(url)    #Air temperature
df1= df1.drop('Time (h)', axis=1)
# Import libraries
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
df1.shape
# Out:
# (8761, 1)

# %%
df1.head()
# Out:
#    Air temperature1 (degC)
# 0                      3.6
# 1                      2.6
# 2                      2.2
# 3                      1.8
# 4                      1.1

# %%
date= pd.date_range('2018-10-01', '2019-10-01', freq='1H')
date= pd.Series(date)
at=pd.Series(df1['Air temperature1 (degC)'])

# %%
date.shape
at.shape
# Out:
# (8761,)

# %%
#df = pd.concat([ at,date], axis=1) # Save original data set, just in case.
df = pd.DataFrame({"ds": date, "y": at})
#df = df.set_index('Date')

# %%
df = df.set_index('ds')
df.head()
# Out:
#                        y
# ds
# 2018-10-01 00:00:00  3.6
# 2018-10-01 01:00:00  2.6
# 2018-10-01 02:00:00  2.2
# 2018-10-01 03:00:00  1.8
# 2018-10-01 04:00:00  1.1

# %%
from fbprophet import Prophet
m = Prophet()
m.fit(df)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods=10)
future.tail()
# Out:
#              ds
# 8766 2019-10-07
# 8767 2019-10-08
# 8768 2019-10-09
# 8769 2019-10-10
# 8770 2019-10-11

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 8766 2019-10-07  6.166484    0.757349   11.760869
# 8767 2019-10-08  6.444636    0.788376   12.096278
# 8768 2019-10-09  6.145658    0.656850   12.039029
# 8769 2019-10-10  6.408475    0.813735   12.096088
# 8770 2019-10-11  6.861837    1.112659   12.397170

# %%
fig1 = m.plot(forecast)

# %%
fig2 = m.plot_components(forecast)

# %%
from fbprophet.plot import plot_plotly
import plotly.offline as py
py.init_notebook_mode()

fig = plot_plotly(m, forecast)  # This returns a plotly Figure
py.iplot(fig)

# %%
from fbprophet.diagnostics import cross_validation, performance_metrics
df_cv = cross_validation(m, horizon='90 days')
df_p = performance_metrics(df_cv)
df_p.head(5)
# Out:
# INFO:fbprophet:Making 1 forecasts with cutoffs between 2019-07-03 00:00:00 and 2019-07-03 00:00:00
#           horizon        mse      rmse       mae      mape  coverage
# 0 8 days 23:00:00  23.844030  4.883035  4.550828  0.368894  0.725581
# 1 9 days 00:00:00  24.367138  4.936308  4.587419  0.375228  0.720930
# 2 9 days 01:00:00  24.842133  4.984188  4.620225  0.380866  0.716279
# 3 9 days 02:00:00  25.317294  5.031629  4.652099  0.386621  0.711628
# 4 9 days 03:00:00  25.685301  5.068067  4.678493  0.390679  0.706977

# %%
from fbprophet.plot import plot_cross_validation_metric
fig3 = plot_cross_validation_metric(df_cv, metric='mape')

# %%
import numpy as np, pandas as pd
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.figsize':(9,7), 'figure.dpi':120})

# Original Series
fig, axes = plt.subplots(3, 2, sharex=True)
axes[0, 0].plot(df.y); axes[0, 0].set_title('Original Series')
plot_acf(df.y, ax=axes[0, 1])

# 1st Differencing
axes[1, 0].plot(df.y.diff()); axes[1, 0].set_title('1st Order Differencing')
plot_acf(df.y.diff().dropna(), ax=axes[1, 1])

# 2nd Differencing
axes[2, 0].plot(df.y.diff().diff()); axes[2, 0].set_title('2nd Order Differencing')
plot_acf(df.y.diff().diff().dropna(), ax=axes[2, 1])

plt.show()

# %%
# PACF plot of 1st differenced series
# p term for AR
plt.rcParams.update({'figure.figsize':(9,3), 'figure.dpi':120})

fig, axes = plt.subplots(1, 2, sharex=True)
axes[0].plot(df.y.diff()); axes[0].set_title('1st Differencing')
axes[1].set(ylim=(0,5))
plot_pacf(df.y.diff().dropna(), ax=axes[1])

plt.show()

# %%
# q term for the MA
import pandas as pd
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.figsize':(9,3), 'figure.dpi':120})

fig, axes = plt.subplots(1, 2, sharex=True)
axes[0].plot(df.y.diff()); axes[0].set_title('1st Differencing')
axes[1].set(ylim=(0,1.2))
plot_acf(df.y.diff().dropna(), ax=axes[1])

plt.show()

# %%
from statsmodels.tsa.arima_model import ARIMA

# 1,1,2 ARIMA Model
model = ARIMA(df.y.dropna(), order=(1,1,1))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                              ARIMA Model Results
# ...
# Dep. Variable:                    D.y   No. Observations:                 8715
# Model:                 ARIMA(1, 1, 1)   Log Likelihood              -15274.015
# Method:                       css-mle   S.D. of innovations              1.396
# Date:                Tue, 05 Nov 2019   AIC                          30556.031
# Time:                        08:20:18   BIC                          30584.322
# Sample:                             1   HQIC                         30565.673
#
# ...

# %%
# Plot residual errors
residuals = pd.DataFrame(model_fit.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %%
# Actual vs Fitted
model_fit.plot_predict(dynamic=False)
plt.show()

# %%
from statsmodels.tsa.stattools import acf

# Create Training and Test
train = df.y[:6000]
test = df.y[6000:]

# %%
# Build Model
# model = ARIMA(train, order=(3,2,1))  
model = ARIMA(train.dropna(), order=(2, 1, 1))  
fitted = model.fit(disp=-1)  

# Forecast
fc, se, conf = fitted.forecast(2761, alpha=0.05)  # 95% conf

# Make as pandas series
fc_series = pd.Series(fc, index=test.index)
lower_series = pd.Series(conf[:, 0], index=test.index)
upper_series = pd.Series(conf[:, 1], index=test.index)

# Plot
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
pip install pmdarima
# Out:
# ...
#      |████████████████████████████████| 1.1MB 2.8MB/s
# ...

# %%
pip install pyramid-arima
# Out:
# ...
#      |████████████████████████████████| 604kB 2.7MB/s
# ...

# %%
from statsmodels.tsa.arima_model import ARIMA
import pmdarima as pm

model = pm.auto_arima(df.y.dropna(), start_p=1, start_q=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())
# Out:
# Fit ARIMA: order=(1, 0, 1); AIC=30663.109, BIC=30691.401, Fit time=1.699 seconds
# Fit ARIMA: order=(0, 0, 0); AIC=62619.729, BIC=62633.874, Fit time=0.016 seconds
# Fit ARIMA: order=(1, 0, 0); AIC=30705.117, BIC=30726.336, Fit time=0.105 seconds
# Fit ARIMA: order=(0, 0, 1); AIC=52629.876, BIC=52651.094, Fit time=0.431 seconds
# Fit ARIMA: order=(2, 0, 1); AIC=30560.518, BIC=30595.882, Fit time=4.268 seconds
# Fit ARIMA: order=(2, 0, 0); AIC=30654.950, BIC=30683.242, Fit time=0.452 seconds
# Fit ARIMA: order=(2, 0, 2); AIC=30545.324, BIC=30587.761, Fit time=9.013 seconds
# Fit ARIMA: order=(3, 0, 3); AIC=29566.771, BIC=29623.354, Fit time=16.112 seconds
# Fit ARIMA: order=(2, 0, 3); AIC=30429.170, BIC=30478.681, Fit time=8.608 seconds
# Fit ARIMA: order=(3, 0, 2); AIC=30494.142, BIC=30543.652, Fit time=3.225 seconds
# Total fit time: 43.999 seconds
#                               ARMA Model Results
# ...
# Dep. Variable:                      y   No. Observations:                 8716
# ...

# %%
model.plot_diagnostics(figsize=(10,8))
plt.show()

# %%
# Forecast
n_periods = 500
fc, confint = model.predict(n_periods=n_periods, return_conf_int=True)
index_of_fc = np.arange(len(df.y), len(df.y)+n_periods)

# make series for plotting purpose
fc_series = pd.Series(fc, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Plot
plt.plot(df.y)
plt.plot(fc_series, color='darkgreen')
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)

plt.title("Final Forecast of WWW Usage")
plt.show()

# %%
# Plot
fig, axes = plt.subplots(2, 1, figsize=(10,5), dpi=100, sharex=True)

# Usual Differencing
axes[0].plot(df[:], label='Original Series')
axes[0].plot(df[:].diff(1), label='Usual Differencing')
axes[0].set_title('Usual Differencing')
axes[0].legend(loc='upper left', fontsize=10)


# Seasinal Dei
axes[1].plot(df[:], label='Original Series')
axes[1].plot(df[:].diff(12), label='Seasonal Differencing', color='green')
axes[1].set_title('Seasonal Differencing')
plt.legend(loc='upper left', fontsize=10)
plt.suptitle('a10 - Drug Sales', fontsize=16)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
import pmdarima as pm

# Seasonal - fit stepwise auto-ARIMA
smodel = pm.auto_arima(df.dropna(), start_p=1, start_q=1,
                         test='adf',
                         max_p=3, max_q=3, m=12, # m=12 for month wise series, seasonal= True 
                         start_P=0, seasonal=True,
                         d=None, D=1, trace=True,
                         error_action='ignore',  
                         suppress_warnings=True, 
                         stepwise=True)

smodel.summary()
# Out:
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=30641.930, BIC=30677.287, Fit time=50.729 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 1, 0, 12); AIC=51605.052, BIC=51619.195, Fit time=0.625 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 1, 0, 12); AIC=33037.036, BIC=33065.322, Fit time=15.457 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=40786.819, BIC=40815.105, Fit time=20.368 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 1, 12); AIC=30483.716, BIC=30526.145, Fit time=92.405 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 0, 12); AIC=32918.930, BIC=32954.288, Fit time=20.785 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 2, 12); AIC=29759.010, BIC=29808.510, Fit time=218.492 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(1, 1, 2, 12); AIC=38857.897, BIC=38900.326, Fit time=97.324 seconds
# ...

# %%
import matplotlib.pyplot as plt
import seaborn; seaborn.set()
df.plot();

# %%
df.plot(alpha=0.5, style='-')
df.resample('B').mean().plot(style=':')
df.asfreq('B').plot(style='--')
plt.legend(['input', 'resample', 'asfreq'],
           loc='upper left')
